# %% [markdown]
# # Phase 3 Project Submission
#
#
# - Student name: Alec Schonfeld
# - Student pace: self paced
# - Scheduled project review date/time:
# - Instructor name: Mark

# %% [markdown]
# # Business Understanding

# %% [markdown]
# ---

# %% [markdown]
# We are reviewing a telecom's dataset to better understand customer churn and the features that can help us predict and mitigate future churn.

# %% [markdown]
# Goal: Identify features that lead to churn and provide strategies for how to better retain customers

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ---

# %%
# Import necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.linear_model import LogisticRegression
plt.style.use('seaborn-v0_8-darkgrid')

# %%
# Load dataset and read it 
df = pd.read_csv(r"C:\Users\alecs\OneDrive\Desktop\Flatiron School\Updated Phase 3 Project\bigml_59c28831336c6604c800002a.csv")
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
#
# [5 rows x 21 columns]

# %%
# Evaluate shape of the dataset

df.shape
# Out:
# (3333, 21)

# %%
# Info on the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(4)
# memory usage: 524.2+ KB

# %% [markdown]
# Dataset info takeaways
# - The target column is "churn" which indicates whether a customer churned or not from the company

# %%
# Describe the dataset 

df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# std          20.069084          9.259435          50.713844        19.922625
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.430000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.790000         235.300000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        total eve charge  total night minutes  total night calls  \
# count       3333.000000          3333.000000        3333.000000
# mean          17.083540           200.872037         100.107711
# std            4.310668            50.573847          19.568609
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        total night charge  total intl minutes  total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        total intl charge  customer service calls
# count        3333.000000             3333.000000
# mean            2.764581                1.562856
# std             0.753773                1.315491
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.780000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %%
# Evaluate the value counts of churn to see values and percentage breakdown

df['churn'].value_counts()
# Out:
# churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
# Evaluate the value counts of account length to see values and percentage breakdown

df['account length'].value_counts()
# Out:
# account length
# 105    43
# 87     42
# 101    40
# 93     40
# 90     39
#        ..
# 243     1
# 200     1
# 232     1
# 5       1
# 221     1
# Name: count, Length: 212, dtype: int64

# %%
# Evaluate missing values across columns

df.isna().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
# Let us evaluate the correlation between features and the target to see what is most correlated

corr = df.corr(numeric_only=True)['churn']

corr_sort = corr.sort_values(ascending=False)

corr_sort
# Out:
# churn                     1.000000
# customer service calls    0.208750
# total day minutes         0.205151
# total day charge          0.205151
# total eve minutes         0.092796
# total eve charge          0.092786
# total intl charge         0.068259
# total intl minutes        0.068239
# total night charge        0.035496
# total night minutes       0.035493
# total day calls           0.018459
# account length            0.016541
# total eve calls           0.009233
# area code                 0.006174
# total night calls         0.006141
# total intl calls         -0.052844
# number vmail messages    -0.089728
# Name: churn, dtype: float64

# %%
# Plot graph of top 5 most correlated

corr_2 = corr_sort.drop(['churn']).head(5)

corr_2.plot(kind='barh')
plt.title('Top 5 Most Correlated Features to Churn')
plt.ylabel('Features')
plt.xlabel('Correlated % to Churn')
plt.show()

# %%
most_correlated = corr_sort[1]
most_correlated
# Out:
# C:\Users\alecs\AppData\Local\Temp\ipykernel_13700\1331651359.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   most_correlated = corr_sort[1]
# 0.2087499987837943

# %% [markdown]
# Takeaways from simple churn correlation metrics for numeric columns
# - It seems that intuitively customer service calls are the most correlated with a customer churning
# - Total day minutes and charge are close 2nd and 3rd while the rest of the features are not very close

# %%
# Lets dive deeper into customer service calls and churn 

avg_calls = df.groupby('churn')['customer service calls'].mean()


avg_calls.plot(kind='barh', color=['blue', 'orange'])
plt.title('Average Number of Calls to Customer Service by Loyalty')
plt.xlabel('Churn')
plt.ylabel('Average Calls to Customer Service')
plt.xticks([0, 1], ['Not Churned', 'Churned'], rotation=0)
plt.show()

# %% [markdown]
# Takeaways from above graph
# - customers who churned made 2 or more calls to customer service on average and is the highest correlated variable with churning

# %%
# Let us look at the object columns in the dataset now

df.select_dtypes('object')
# Out:
#      state phone number international plan voice mail plan
# 0       KS     382-4657                 no             yes
# 1       OH     371-7191                 no             yes
# 2       NJ     358-1921                 no              no
# 3       OH     375-9999                yes              no
# 4       OK     330-6626                yes              no
# ...    ...          ...                ...             ...
# 3328    AZ     414-4276                 no             yes
# 3329    WV     370-3271                 no              no
# 3330    RI     328-8230                 no              no
# 3331    CT     364-6381                yes              no
# 3332    TN     400-4344                 no             yes
#
# [3333 rows x 4 columns]

# %% [markdown]
# There are 4 object date type columns but I believe we can ignore phone number as that is just a random string of phone numebrs and will not be indicative of churn and we can also ignore state as it would produce too many columns
# - Let us focus on State, international plan, voice mail plan

# %%
# Lets plot state 

df.groupby(["state", "churn"]).size().unstack().plot(kind='bar', stacked=True, figsize=(30,10))
# Out:
# <Axes: xlabel='state'>

# %%
# Visualize by percentage
percentage_df = (
    df.groupby(["state", "churn"]).size()
    .unstack()  # Pivot to create columns for each 'churn' value
    .apply(lambda x: x / x.sum(), axis=1)  # Convert counts to percentages
)

# Sort by the percentage of churn = True (descending order)
sorted_percentage_df = percentage_df.sort_values(by=True, ascending=False)

# Select the top 5 states
sorted_df_top5 = sorted_percentage_df.head(5)

# Plot stacked bar chart
ax = sorted_df_top5.plot(kind='barh', stacked=True, figsize=(10, 10))

# Add labels to bars using bar_label
for container in ax.containers:
    ax.bar_label(
        container,
        fmt="%.1f%%",  # Format as percentage
        label_type="center",  # Center labels inside the bars
        fontsize=10,
        color="white",
        labels=[f"{v * 100:.1f}%" for v in container.datavalues],  # Convert to percentage
    )

# Add a title and labels for better visualization
plt.title("Top 5 States by Percentage of Churn = True", fontsize=16)
plt.ylabel("State", fontsize=14)
plt.xlabel("Percentage", fontsize=14)

# Add a legend outside the graph
plt.legend(
    title="Churn",
    fontsize=12,
    title_fontsize=14,
    loc='center left',  # Position the legend to the left
    bbox_to_anchor=(1, 0.5)  # Move the legend outside the plot
)

# Show the plot
plt.tight_layout()  # Adjust layout to ensure everything fits
plt.show()

# %% [markdown]
# Takeaways from the above graph:
# - NJ, CA, and TX have the highest churn rate all 25% and higher
# - It is interesting that some of the biggest states have the highest churn

# %%
# Visualize by percentage
percentage_df = (
    df.groupby(["state", "churn"]).size()
    .unstack()  # Pivot to create columns for each 'churn' value
    .apply(lambda x: x / x.sum(), axis=1)  # Convert counts to percentages
)

# Sort by the percentage of churn = True (descending order)
sorted_percentage_df = percentage_df.sort_values(by=True, ascending=True)

# Select the top 5 states
sorted_df_top5 = sorted_percentage_df.head(5)

# Plot stacked bar chart
ax = sorted_df_top5.plot(kind='barh', stacked=True, figsize=(10, 10))

# Add labels to bars using bar_label
for container in ax.containers:
    ax.bar_label(
        container,
        fmt="%.1f%%",  # Format as percentage
        label_type="center",  # Center labels inside the bars
        fontsize=10,
        color="white",
        labels=[f"{v * 100:.1f}%" for v in container.datavalues],  # Convert to percentage
    )

# Add a title and labels for better visualization
plt.title("Bottom 5 States by Percentage of Churn = True", fontsize=16)
plt.xlabel("State", fontsize=14)
plt.ylabel("Percentage", fontsize=14)

# Add a legend outside the graph
plt.legend(
    title="Churn",
    fontsize=12,
    title_fontsize=14,
    loc='center left',  # Position the legend to the left
    bbox_to_anchor=(1, 0.5)  # Move the legend outside the plot
)

# Show the plot
plt.tight_layout()  # Adjust layout to ensure everything fits
plt.show()

# %%
# Lets look at international plan correlation to churn 

df.groupby(["international plan", "churn"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,6))
# Out:
# <Axes: xlabel='international plan'>

# %%
# visualize by percentage
percentage_df = (
    df.groupby(["international plan", "churn"]).size()
    .unstack()  # Pivot to create columns for each 'churn' value
    .apply(lambda x: x / x.sum(), axis=1))
    

    # Sort by the percentage of churn = True (descending order)
sorted_percentage_df = percentage_df.sort_values(by=True, ascending=False)

sorted_df_top5 = sorted_percentage_df.head(5)

ax= sorted_df_top5.plot(kind='bar',stacked=True, figsize = (10,6))


# Add labels to bars using bar_label
for container in ax.containers:
    ax.bar_label(
        container,
        fmt="%.1f%%",  # Format as percentage
        label_type="center",  # Center labels inside the bars
        fontsize=10,
        color="white",
         labels=[f"{v * 100:.1f}%" for v in container.datavalues], )
        
# Add a title and labels for better visualization
plt.title("international plan", fontsize=16)
plt.xlabel("international plan", fontsize=14)
plt.ylabel("Percentage", fontsize=14)
plt.legend(title="Churn", fontsize=12)
plt.show()

# %% [markdown]
# Takeaways from above graph:
# - Churn Rates w/ international plan = 42.4%
# - Churn rates w/o international plan = 11.5%
# - There is a big discrepancy here of 30.9%

# %%
# Lets look at voicemail plan correlation to churn 

df.groupby(["voice mail plan", "churn"]).size().unstack().plot(kind='bar', stacked=True, figsize=(30,10))
# Out:
# <Axes: xlabel='voice mail plan'>

# %%
# visualize by percentage
percentage_df = (
    df.groupby(["voice mail plan", "churn"]).size()
    .unstack()  # Pivot to create columns for each 'churn' value
    .apply(lambda x: x / x.sum(), axis=1))
    

    # Sort by the percentage of churn = True (descending order)
sorted_percentage_df = percentage_df.sort_values(by=True, ascending=False)

sorted_df_top5 = sorted_percentage_df.head(5)

ax= sorted_df_top5.plot(kind='bar',stacked=True, figsize = (10,6))


# Add labels to bars using bar_label
for container in ax.containers:
    ax.bar_label(
        container,
        fmt="%.1f%%",  # Format as percentage
        label_type="center",  # Center labels inside the bars
        fontsize=10,
        color="white",
         labels=[f"{v * 100:.1f}%" for v in container.datavalues], )
        
# Add a title and labels for better visualization
plt.title("voice mail plan", fontsize=16)
plt.xlabel("voice mail plan", fontsize=14)
plt.ylabel("Percentage", fontsize=14)
plt.legend(title="Churn", fontsize=12)
plt.show()

# %% [markdown]
# Takeaways from above graph:
# - Churn rate w/ voice mail plan is 16.7%
# - Churn rate w/o voice mail plan is 8.7%
# - There is a significant 8% discrepancy but much less than the international plan

# %% [markdown]
# ## Setting up our model
# We will use logistic regression since our target is a bool dtype

# %%
df.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
# convert to int df

df_int = df.select_dtypes(include =['int','bool'])

# %%
# Import the relevant function
from sklearn.model_selection import train_test_split

# Split df into X and y
X = df_int.drop("churn", axis=1)
y = df_int["churn"]

# Perform train-test split with random_state=42 and stratify=y
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (2666, 8)
# (2666,)

# %%
# Build a logistic regression model using statsmodels
import statsmodels.api as sm
X = sm.tools.add_constant(X)
logit_model1 = sm.Logit(y, X)
result = logit_model1.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.387924
#          Iterations 6

# %%
# Summary Table 

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  churn   No. Observations:                 3333
# Model:                          Logit   Df Residuals:                     3324
# Method:                           MLE   Df Model:                            8
# Date:                Wed, 04 Dec 2024   Pseudo R-squ.:                 0.06250
# Time:                        10:35:06   Log-Likelihood:                -1293.0
# converged:                       True   LL-Null:                       -1379.1
# Covariance Type:            nonrobust   LLR p-value:                 4.064e-33
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -2.8772      0.711     -4.048      0.000      -4.270      -1.484
# account length             0.0013      0.001      1.022      0.307      -0.001       0.004
# area code               8.177e-05      0.001      0.069      0.945      -0.002       0.002
# number vmail messages     -0.0221      0.004     -5.099      0.000      -0.031      -0.014
# total day calls            0.0032      0.003      1.272      0.203      -0.002       0.008
# total eve calls            0.0013      0.003      0.514      0.607      -0.004       0.006
# total night calls          0.0018      0.003      0.701      0.483      -0.003       0.007
# total intl calls          -0.0637      0.022     -2.843      0.004      -0.108      -0.020
# customer service calls     0.3995      0.035     11.440      0.000       0.331       0.468
# ==========================================================================================
# """

# %% [markdown]
# # Correlation Matrix

# %%
# confirming there is no colinearity between features

import pandas as pd

# Calculate correlation matrix
correlation_matrix = X.corr()

# Display the matrix
print(correlation_matrix)

# Visualize using a heatmap (optional)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
#                         const  account length  area code  \
# const                     NaN             NaN        NaN
# account length            NaN        1.000000  -0.012463
# area code                 NaN       -0.012463   1.000000
# number vmail messages     NaN       -0.004628  -0.001994
# total day calls           NaN        0.038470  -0.009646
# total eve calls           NaN        0.019260  -0.011886
# total night calls         NaN       -0.013176   0.016522
# total intl calls          NaN        0.020661  -0.024179
# customer service calls    NaN       -0.003796   0.027572
#
#                         number vmail messages  total day calls  \
# const                                     NaN              NaN
# account length                      -0.004628         0.038470
# area code                           -0.001994        -0.009646
# number vmail messages                1.000000        -0.009548
# total day calls                     -0.009548         1.000000
# total eve calls                     -0.005864         0.006462
# total night calls                    0.007123        -0.019557
# total intl calls                     0.013957         0.004574
# customer service calls              -0.013263        -0.018942
#
#                         total eve calls  total night calls  total intl calls  \
# const                               NaN                NaN               NaN
# account length                 0.019260          -0.013176          0.020661
# area code                     -0.011886           0.016522         -0.024179
# number vmail messages         -0.005864           0.007123          0.013957
# total day calls                0.006462          -0.019557          0.004574
# total eve calls                1.000000           0.007710          0.017434
# total night calls              0.007710           1.000000          0.000305
# total intl calls               0.017434           0.000305          1.000000
# customer service calls         0.002423          -0.012802         -0.017561
#
#                         customer service calls
# const                                      NaN
# account length                       -0.003796
# area code                             0.027572
# number vmail messages                -0.013263
# total day calls                      -0.018942
# total eve calls                       0.002423
# total night calls                    -0.012802
# total intl calls                     -0.017561
# customer service calls                1.000000

# %% [markdown]
# Key Takeaways from the Matrix
# - Most of the variables show very low correlation with each other, indicating minimal multicollinearity.
# - The correlation values are close to 0, suggesting that the features are relatively independent.

# %% [markdown]
# Key Takeaways from the Logistic Regression Results
#
# Overall Model Performance
# - Pseudo R-squared: 0.06250
#
# - The model explains about 6.25% of the variance in churn, which is relatively low. This suggests that there may be other factors influencing churn that are not included in this model.
#
# - The model as a whole is statistically significant, meaning that at least one predictor contributes to the prediction of churn.
#
# Insights and Recommendations
#
# Customer Service Calls:
#
# - A strong and significant predictor of churn. Focus on improving customer service quality and addressing frequent complaints to reduce churn.
#
# Voicemail Usage:
#
# - Voicemail usage is negatively correlated with churn. Consider promoting or improving voicemail-related services to enhance customer satisfaction and retention.
#
# International Calls:
#
# - Customers making more international calls are less likely to churn. Highlight and market international calling features to retain these customers.
#
# Irrelevant Features:
#
# - Features like account length, area code, and total calls at different times of the day do not significantly contribute to the model. Consider excluding them to simplify the model and improve interpretability.

# %% [markdown]
# # Optimized Model

# %% [markdown]
# Now we will choose features that showed to be significant predictors: number of voicemail message, total intl calls, customer service calls

# %%
# Your code here
relevant_columns = ['customer service calls', 'international plan', 'voice mail plan', 'total intl calls','churn']
dummy_dataframe = pd.get_dummies(df[relevant_columns], drop_first=True, dtype=float)

dummy_dataframe = dummy_dataframe.dropna()

y = dummy_dataframe['churn']
X = dummy_dataframe.drop(columns=['churn'], axis=1)

X = sm.tools.add_constant(X)
logit_model2 = sm.Logit(y, X)
result = logit_model2.fit()

result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.357915
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  churn   No. Observations:                 3333
# Model:                          Logit   Df Residuals:                     3328
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 04 Dec 2024   Pseudo R-squ.:                  0.1350
# Time:                        10:35:09   Log-Likelihood:                -1192.9
# converged:                       True   LL-Null:                       -1379.1
# Covariance Type:            nonrobust   LLR p-value:                 2.514e-79
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -2.3702      0.139    -17.007      0.000      -2.643      -2.097
# customer service calls     0.4426      0.037     12.105      0.000       0.371       0.514
# total intl calls          -0.0746      0.023     -3.185      0.001      -0.121      -0.029
# international plan_yes     1.9658      0.136     14.468      0.000       1.700       2.232
# voice mail plan_yes       -0.8341      0.138     -6.048      0.000      -1.104      -0.564
# ==========================================================================================
# """

# %%
# lets add total day minutes, total day charge from our initial correlation analysis
# Your code here
relevant_columns_2 = ['customer service calls', 'international plan', 'voice mail plan', 
                      'total intl calls','churn','total day charge','total day minutes']
dummy_dataframe_2 = pd.get_dummies(df[relevant_columns_2],drop_first=True,dtype=float)

dummy_dataframe_2 = dummy_dataframe_2.dropna()

y2= dummy_dataframe_2['churn']
X2 = dummy_dataframe_2.drop(columns=['churn'],axis=1)

X2 = sm.tools.add_constant(X2)
logit_model3 = sm.Logit(y2,X2)
result = logit_model3.fit()

result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.334777
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  churn   No. Observations:                 3333
# Model:                          Logit   Df Residuals:                     3326
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 04 Dec 2024   Pseudo R-squ.:                  0.1909
# Time:                        10:35:09   Log-Likelihood:                -1115.8
# converged:                       True   LL-Null:                       -1379.1
# Covariance Type:            nonrobust   LLR p-value:                1.506e-110
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -4.8272      0.265    -18.247      0.000      -5.346      -4.309
# customer service calls     0.4869      0.038     12.735      0.000       0.412       0.562
# total intl calls          -0.0834      0.024     -3.430      0.001      -0.131      -0.036
# total day charge           1.1984     18.960      0.063      0.950     -35.962      38.358
# total day minutes         -0.1911      3.223     -0.059      0.953      -6.508       6.126
# international plan_yes     1.9999      0.142     14.105      0.000       1.722       2.278
# voice mail plan_yes       -0.8746      0.142     -6.162      0.000      -1.153      -0.596
# ==========================================================================================
# """

# %% [markdown]
# Observations:
# - The new model has the highest Pseudo R-squared (0.1909), meaning it explains 19.09% of the variance, which is a significant improvement over the previous models.
# - The Log-Likelihood (-1115.8) indicates better model fit compared to the earlier models (-1192.9 and -1189.3).
# - The LLR p-value is highly significant in all models, but the new model performs better overall.
# - The new model added total day charge and total day minutes, but these variables are not significant (p > 0.05), indicating they do not have a meaningful relationship with churn.

# %% [markdown]
# # Evaluating Our Models

# %% [markdown]
# 1. Baseline Model

# %%
# Import scikit packages to define precision, recall, accuracy and f1 for our models

from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# Your code here

logreg = LogisticRegression(fit_intercept=False, C=1e16, solver='liblinear')
logreg.fit(X_train, y_train)

logreg
# Out:
# LogisticRegression(C=1e+16, fit_intercept=False, solver='liblinear')

# %%
X_train.columns
# Out:
# Index(['customer service calls', 'international plan', 'voice mail plan',
#        'total intl calls', 'total day charge', 'total day minutes'],
#       dtype='object')

# %%
# Calculate the TRP and FPR for ROC / AOC results

# Import roc_curve, auc
from sklearn.metrics import roc_curve, auc

# Calculate the probability scores of each point in the training set
y_train_score = logreg.decision_function(X_train)

# Calculate the fpr, tpr, and thresholds for the training set
train_fpr, train_tpr, thresholds = roc_curve(y_train, y_train_score)

# Calculate the probability scores of each point in the test set
y_test_score = logreg.decision_function(X_test)

# Calculate the fpr, tpr, and thresholds for the test set
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, y_test_score)

# %%
print('Train AUC: {}'.format(auc(train_fpr, train_tpr)))
print('Test AUC: {}'.format(auc(test_fpr, test_tpr)))

plt.figure(figsize=(10, 8))
lw = 2

plt.plot(train_fpr, train_tpr, color='blue',
         lw=lw, label='Train ROC curve')
plt.plot(test_fpr, test_tpr, color='darkorange',
         lw=lw, label='Test ROC curve')

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Train AUC: 0.6451320820458275
# Test AUC: 0.6367421194416262

# %% [markdown]
# Add an intercept to the model

# %%
# Create new model
logregi = LogisticRegression(fit_intercept=True, C=1e16, solver='liblinear')
logregi.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1e+16, solver='liblinear')

# %%
# Lets evaluate accuracy scores for our baseline model

y_hat_train = logregi.predict(X_train)
y_hat_test = logregi.predict(X_test)

# %%
# Initial model plots
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, y_hat_test)
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, y_hat_train)


print('Custom Model Test AUC: {}'.format(auc(test_fpr, test_tpr)))
print('Custome Model Train AUC: {}'.format(auc(train_fpr, train_tpr)))

plt.figure(figsize=(10,8))
lw = 2

plt.plot(test_fpr, test_tpr, color='darkorange',
         lw=lw, label='Custom Model Test ROC curve')
plt.plot(train_fpr, train_tpr, color='blue',
         lw=lw, label='Custom Model Train ROC curve')


# Second model plots
y_test_score = logreg.decision_function(X_test)
y_train_score = logreg.decision_function(X_train)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, y_test_score)
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, y_train_score)

print('Scikit-learn Model 1 Test AUC: {}'.format(auc(test_fpr, test_tpr)))
print('Scikit-learn Model 1 Train AUC: {}'.format(auc(train_fpr, train_tpr)))


plt.plot(test_fpr, test_tpr, color='yellow',
         lw=lw, label='Scikit learn Model 1 Test ROC curve')
plt.plot(train_fpr, train_tpr, color='gold',
         lw=lw, label='Scikit learn Model 1 Train ROC curve')


# Third model plots
y_test_score = logregi.decision_function(X_test)
y_train_score = logregi.decision_function(X_train)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, y_test_score)
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, y_train_score)

print('Scikit-learn Model 2 with intercept Test AUC: {}'.format(auc(test_fpr, test_tpr)))
print('Scikit-learn Model 2 with intercept Train AUC: {}'.format(auc(train_fpr, train_tpr)))


plt.plot(test_fpr, test_tpr, color='purple',
         lw=lw, label='Scikit learn Model 2 with intercept Test ROC curve')
plt.plot(train_fpr, train_tpr, color='red',
         lw=lw, label='Scikit learn Model 2 with intercept Train ROC curve')

# Formatting
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Custom Model Test AUC: 0.504950495049505
# Custome Model Train AUC: 0.5157022216924473
# Scikit-learn Model 1 Test AUC: 0.6367421194416262
# Scikit-learn Model 1 Train AUC: 0.6451320820458275
# Scikit-learn Model 2 with intercept Test AUC: 0.6342406325438197
# Scikit-learn Model 2 with intercept Train AUC: 0.6519539523752762

# %% [markdown]
# Key Insights
# Custom Model Performs Poorly:
#
# Both the train and test ROC curves are close to the diagonal, with little distinction between positive and negative classes. The low performance indicates that the custom model may need further refinement or a better feature set.
# Scikit-learn Models Generalize Slightly Better:
#
# Model 2 with Intercept performs slightly better than Model 1, suggesting the intercept or additional features/parameters in Model 2 helped marginally improve the predictions.
# Low Overall Predictive Power:
#
# All models have ROC curves that hover near the diagonal, indicating that none of them have strong discriminative ability between classes.
# Test and Train Curves Are Close:
#
# For all models, the training and testing curves are close to each other, suggesting that there’s no severe overfitting. However, the models are underperforming overall.

# %% [markdown]
# # Preprocessed Data Model

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
scaler = StandardScaler()

# Fit the scaler on the training data and transform it
X_train_scaled = scaler.fit_transform(X_train)

# Apply the same transformation to the test data
X_test_scaled = scaler.transform(X_test)

# %%
logreg_scaled = LogisticRegression(max_iter=1000, random_state=42)

# Fit the model
logreg_scaled.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
# Predictions on training and test data
y_train_pred = logreg.predict(X_train_scaled)
y_test_pred = logreg.predict(X_test_scaled)

# Predict probabilities for ROC AUC
y_train_prob = logreg.predict_proba(X_train_scaled)[:, 1]
y_test_prob = logreg.predict_proba(X_test_scaled)[:, 1]
# Out:
# C:\Users\alecs\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\alecs\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\alecs\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\alecs\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# Training performance
print("Training Accuracy:", accuracy_score(y_train, y_train_pred))
print("Training ROC AUC:", roc_auc_score(y_train, y_train_prob))

# Testing performance
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred))
print("Testing ROC AUC:", roc_auc_score(y_test, y_test_prob))
# Out:
# Training Accuracy: 0.594523630907727
# Training ROC AUC: 0.6233484013533711
# Testing Accuracy: 0.6071964017991005
# Testing ROC AUC: 0.6127418395549802

# %% [markdown]
# # 2. Model #3

# %% [markdown]
# # Set Up Decision Tree Model

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc
plt.style.use('seaborn-v0_8-darkgrid')

# %%
# Create X and y 
y = df['churn']
X = df[['customer service calls', 'international plan', 'voice mail plan', 
                      'total intl calls','total day charge','total day minutes']]

# Split into training and test sets
SEED = 1
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=SEED)

# %%
# Map 'yes' to 1 and 'no' to 0 for both columns
X['international plan'] = X['international plan'].map({'yes': 1, 'no': 0})
X['voice mail plan'] = X['voice mail plan'].map({'yes': 1, 'no': 0})


X_train['international plan'] = X_train['international plan'].map({'yes': 1, 'no': 0})
X_train['voice mail plan'] = X_train['voice mail plan'].map({'yes': 1, 'no': 0})

X_test['international plan'] = X_test['international plan'].map({'yes': 1, 'no': 0})
X_test['voice mail plan'] = X_test['voice mail plan'].map({'yes': 1, 'no': 0})
# Out:
# C:\Users\alecs\AppData\Local\Temp\ipykernel_13700\4125705888.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['international plan'] = X['international plan'].map({'yes': 1, 'no': 0})
# C:\Users\alecs\AppData\Local\Temp\ipykernel_13700\4125705888.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['voice mail plan'] = X['voice mail plan'].map({'yes': 1, 'no': 0})

# %%
print(X.dtypes)
# Out:
# customer service calls      int64
# international plan          int64
# voice mail plan             int64
# total intl calls            int64
# total day charge          float64
# total day minutes         float64
# dtype: object

# %%
# Train the classifier using training data 
dt = DecisionTreeClassifier(criterion='entropy', random_state=SEED)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1)

# %%
# Make predictions using test set 
y_pred = dt.predict(X_test)

# Check the AUC of predictions
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.7263359548296027

# %% [markdown]
# # Identify optimal tree length

# %%
# Identify the optimal tree depth for given data
max_depths = list(range(1, 33))
train_results = []
test_results = []
for max_depth in max_depths:
    dt = DecisionTreeClassifier(criterion='entropy', max_depth=max_depth, random_state=42)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    # Add auc score to previous train results
    train_results.append(roc_auc)
    y_pred = dt.predict(X_test)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    # Add auc score to previous test results
    test_results.append(roc_auc)

plt.figure(figsize=(12,6))
plt.plot(max_depths, train_results, 'b', label='Train AUC')
plt.plot(max_depths, test_results, 'r', label='Test AUC')
plt.ylabel('AUC score')
plt.xlabel('Tree depth')
plt.legend()
plt.show()

# %% [markdown]
# Summary
#
# - The model performs best with tree depths between 4 and 6.
# - The test AUC improves initially (up to a depth of ~4–6) but plateaus and fluctuates with deeper trees, showing no additional improvement.
# - A large gap between Train AUC and Test AUC for deeper trees highlights overfitting, where the model memorizes training data instead of generalizing.

# %% [markdown]
# # Min Sample Split

# %%
# Define a range of values for min_samples_split
min_samples_splits = np.linspace(0.1, 1.0, 10, endpoint=True) * len(X_train)
min_samples_splits = min_samples_splits.astype(int)

train_results = []
test_results = []

for min_samples_split in min_samples_splits:
    # Initialize the Decision Tree Classifier
    dt = DecisionTreeClassifier(criterion='entropy', min_samples_split=min_samples_split, random_state=42)
    dt.fit(X_train, y_train)
    
    # Predict probabilities for training set
    train_pred = dt.predict_proba(X_train)[:, 1]
    false_positive_rate, true_positive_rate, _ = roc_curve(y_train, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    train_results.append(roc_auc)
    
    # Predict probabilities for test set
    test_pred = dt.predict_proba(X_test)[:, 1]
    false_positive_rate, true_positive_rate, _ = roc_curve(y_test, test_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    test_results.append(roc_auc)

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(min_samples_splits, train_results, 'b', label='Train AUC')
plt.plot(min_samples_splits, test_results, 'r', label='Test AUC')
plt.xlabel('Min. Sample Splits')
plt.ylabel('AUC')
plt.legend()
plt.title('AUC vs Min. Sample Splits')
plt.show()

# %% [markdown]
# Summary
#
# - Small min_samples_split leads to overfitting (high train AUC, low test AUC).
# - Intermediate values (e.g., 500–1500) provide the best test AUC and generalization.
# - Increasing the min_samples_split value reduces the model complexity by requiring more samples to split a node.

# %% [markdown]
# # Min Sample Leafs

# %%
# Calculate the optimal value for minimum sample leafs
min_samples_leafs = np.linspace(1, 5, 10, endpoint=True)  # Ensure 10 is an integer
train_results = []
test_results = []

for min_samples_leaf in min_samples_leafs:
    dt = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=int(min_samples_leaf), random_state=SEED)  # Ensure min_samples_leaf is an integer
    dt.fit(X_train, y_train)
    
    # Calculate AUC for training set
    train_pred = dt.predict(X_train)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    train_results.append(roc_auc)
    
    # Calculate AUC for test set
    y_pred = dt.predict(X_test)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    test_results.append(roc_auc)

# Plot the results
plt.figure(figsize=(12,6))
plt.plot(min_samples_leafs, train_results, 'b', label='Train AUC')
plt.plot(min_samples_leafs, test_results, 'r', label='Test AUC')
plt.ylabel('AUC score')
plt.xlabel('Min. Sample Leafs')
plt.legend()
plt.show()

# %% [markdown]
# Key Takeaways
# - The optimal range appears to be around 4–5, where the test AUC starts to improve while the train AUC is still reasonably high.
# - For very small values of min_samples_leaf (e.g., 1), the Train AUC is very high, showing the model is overfitting to the training data.
# - The test values  improvement at higher values indicates better generalization as the model avoids overfitting.

# %% [markdown]
# # Maximum Features

# %%
# Find the best value for optimal maximum feature size
max_features = list(range(1, X_train.shape[1]))
train_results = []
test_results = []
for max_feature in max_features:
    dt = DecisionTreeClassifier(criterion='entropy', max_features=max_feature, random_state=SEED)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    train_results.append(roc_auc)
    y_pred = dt.predict(X_test)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    test_results.append(roc_auc)

plt.figure(figsize=(12,6))
plt.plot(max_features, train_results, 'b', label='Train AUC')
plt.plot(max_features, test_results, 'r', label='Test AUC')
plt.ylabel('AUC score')
plt.xlabel('max features')
plt.legend()
plt.show()

# %% [markdown]
# Key Takeaways
#
# - No clear effect on the training dataset - flat AUC
# - Some fluctuations in test AUC but not definitive enough to make a judgement
# - Highest AUC value seen at 4

# %% [markdown]
# # Final Model

# %%
# Train a classifier with optimal values identified above
dt = DecisionTreeClassifier(
    criterion='entropy',
    max_features=4,
    max_depth=5,
    min_samples_split=1000,
    min_samples_leaf=5,  # Use an integer value
    random_state=SEED
)

dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.5921556765476911

# %% [markdown]
# # Conclusion and Recommendation
#
# ## Feature Selection
# - When building our decision classifier model, we needed to decide which factors (or "features") are most important for predicting the outcome—whether a customer is likely to churn (leave the service) or stay. To do this, we analyzed how strongly different factors correlate with churn. Simply put:
#
# - A correlation measures how closely one factor (like "customer service calls") is related to another (like whether the customer churns).
# - We focused on features that showed the strongest relationships to churn, as they are more likely to influence the model’s predictions.
#
# The features we selected are:
#
# 1. Customer Service Calls: Customers who make frequent calls to customer service are more likely to churn. This suggests dissatisfaction or unresolved issues.
# 2. International Plan: Customers with an international calling plan are more likely to churn. This might indicate dissatisfaction with international service pricing or competitors offering better deals.
# 3. Voice Mail Plan: The presence or absence of a voicemail plan also contributes to predicting churn. It could reflect usage patterns or preferences.
# 4. Total International Calls: The number of international calls made could signal specific customer behaviors or service usage patterns that relate to churn.
#
#
# ## Model Results and Next Steps
# Takeaways from the Decision Classifier Model
#
# The decision classifier model helps us predict churn by learning patterns in these selected features. Here’s what we learned:
#
# Customer Service Calls is the Strongest Predictor:
#
# The more frequently a customer contacts customer service, the higher the likelihood of churn. This suggests that resolving customer complaints efficiently could reduce churn.
# Customers with an International Plan are at Higher Risk:
#
# These customers may be dissatisfied with the cost or quality of the international calling plan. Improving this service could improve retention.
# Voice Mail Plan is Predictive:
#
# While less obvious, whether a customer has a voicemail plan or not may relate to overall service usage or satisfaction. This could be worth exploring further.
# Total International Calls Adds Context:
#
# Customers making frequent international calls may represent a specific customer segment. Understanding their unique needs (e.g., better international rates or service quality) could reduce churn.
